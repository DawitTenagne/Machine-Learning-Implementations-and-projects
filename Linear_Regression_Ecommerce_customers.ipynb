# %% [markdown]
# <a href="https://colab.research.google.com/github/DawitTenagne/Machine-Learning-Implementations-and-projects/blob/main/Linear_Regression_Ecommerce_customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
